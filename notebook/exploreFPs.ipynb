# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/FPsProperty.csv')

# %%
data.columns
# Out:
# Index(['Name', 'Ex max (nm)', 'Em max (nm)', 'Stokes Shift (nm)',
#        'Extinction Coefficient', 'Quantum Yield', 'Brightness', 'pKa',
#        'Oligomerization', 'Maturation (min)', 'Lifetime (ns)',
#        'Molecular Weight (kDa)', 'Switch Type', 'Aliases'],
#       dtype='object')

# %%
sns.scatterplot(data, x='Ex max (nm)', y='Em max (nm)')
# Out:
# <AxesSubplot:xlabel='Ex max (nm)', ylabel='Em max (nm)'>
